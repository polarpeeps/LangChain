# %%
import os
os.environ["OPENAI_API_KEY"] = "sk-proj"

# %%
# %pip install -q youtube-transcript-api langchain-community langchain-openai faiss-cpu tiktoken python-dotenv
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# ## Step 1a - Indexing (Document Ingestion)

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api._errors import TranscriptsDisabled

video_id = "U2-JPqrALsA"  # only the ID, not full URL
try:
    ytt_api = YouTubeTranscriptApi()
    transcript_list = ytt_api.fetch(video_id, languages=["en"])

    # Flatten it to plain text
    transcript = " ".join(snippet.text for snippet in transcript_list)
    print(transcript)

except TranscriptsDisabled:
    print("No captions available for this video.")
# Out:
# Before you try to access the dark web, let me show you how to do it safely
# and securely. I'll show you three ways, starting with the most insecure
# way, the way you're about to try. You're going to get hacked and then
# I'll end with the most secure way, like you're invisible, that can't
# touch you. You're Edward Snowden, Snowden level security, kind
# of a cool name for a company. Actually dips before we go to
# number one, and I'll let you loose. You got to know the
# dark web isn't all bad. It was actually created with good
# intentions to give people anonymity and a platform for free expression, and
# it has a ton of legitimate uses. So think journalists try to communicate
# with people who want to stay hidden like Edward Snowden or people trying to
# keep their activities hidden from their government like Edward Snowden. Or if you want to play chess
# without anybody watching, yes, you can play chess on the dark web like
# ...

# %%
transcript_list
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text='Before you try to access the dark web,', start=0.15, duration=1.74), FetchedTranscriptSnippet(text="let me show you how to do it safely\nand securely. I'll show you three ways,", start=1.89, duration=3.06), FetchedTranscriptSnippet(text="starting with the most insecure\nway, the way you're about to try.", start=4.98, duration=2.7), FetchedTranscriptSnippet(text="You're going to get hacked and then\nI'll end with the most secure way,", start=7.74, duration=3.06), FetchedTranscriptSnippet(text="like you're invisible, that can't\ntouch you. You're Edward Snowden,", start=10.86, duration=3.27), FetchedTranscriptSnippet(text='Snowden level security, kind\nof a cool name for a company.', start=14.22, duration=2.67), FetchedTranscriptSnippet(text="Actually dips before we go to\nnumber one, and I'll let you loose.", start=16.89, duration=2.88), FetchedTranscriptSnippet(text="You got to know the\ndark web isn't all bad.", start=19.86,
# ...

# %% [markdown]
# ## Step 1b - Indexing (Text Splitting)

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
chunks = splitter.create_documents([transcript])

# %%
len(chunks)
# Out:
# 25

# %%
chunks[10]
# Out:
# Document(metadata={}, page_content="secure but not the most secure. I probably still wouldn't do this\nif I were searching for stuff, you know what I mean? This will\ninvolve the same thing as level one, but adding an extra layer of\nprotection, kind of like an onion. We'll still have our same\ntour browser, we'll need that. But before we connect to the Tor network, we'll first connect to V P N and we'll\nalso change some settings in our tour browser that are highly recommended\nbecause you don't want to be sitting there hanging out in the dark web and all of\na sudden you get a phone call or a knock on the door and you're\nlike, what did I do? True story from someone Coffee break. So back here at my TOR browser, I'm going to disconnect from\nthe TOR network and I'll\njust close my TOR browser. Now, I'll set up V P N\nreal quick. I'm using nord. You can use whatever you\nwant as long as you trust it. And then I'll connect to V P N and then\nlaunch my TOR browser. Now, why do this? Wh
# ...

# %% [markdown]
# ## Step 1c & 1d - Indexing (Embedding Generation and Storing in Vector Store)

# %%
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
vector_store = FAISS.from_documents(chunks, embeddings)

# %%
vector_store.index_to_docstore_id
# Out:
# {0: '1ff87b25-f2bc-4341-bf92-e2b8b24be939',
#  1: 'b55cdbd5-d7f9-4420-b83f-aef604a1c7c2',
#  2: '1bac35f4-c4b3-42ed-becc-3aafdc6b580e',
#  3: '908fabcd-60ff-45c6-9305-0faca8d7f687',
#  4: '967159af-a5bf-47f9-9923-28c500bfe2fe',
#  5: 'efaaf164-d01f-4f1e-8d77-f657f1190284',
#  6: '8561e4b4-4d4c-4c30-b543-df3869892401',
#  7: '18596527-e844-4581-a6d3-68ca060eb479',
#  8: '6c1ad42f-0dcf-437b-a381-57a85946298d',
#  9: 'e59a9bef-91ba-4bdb-b8ba-d7d4ecad1d18',
#  10: '27d5a8c7-6f40-4a58-a5b6-75e1edec952e',
#  11: 'f787ee35-3c16-4aff-a0fb-29c291c54e2d',
#  12: '154cd4a8-ca5b-4f16-8dac-410de38712a8',
#  13: '63efcc2a-aba3-4aea-8cca-8d0dc1468d46',
#  14: 'f3a1960f-f992-4378-8919-43ebd88a7511',
#  15: '0844db15-df36-4408-8a7c-c77bd31db443',
#  16: 'e57bae20-a5ab-474f-ac5f-24c897524724',
#  17: 'e6899f25-349a-4534-a453-499bc7b40b42',
#  18: 'edc318ca-c80b-4277-8f2e-2040b7c183a2',
#  19: '24ad31ba-d5fd-47ac-97b9-23773acc050e',
#  20: '7bcaf84b-92d3-44ba-bd73-c3cfebc33042',
# ...

# %%
vector_store.get_by_ids(['62c9a0e6-0344-4a47-b30d-cc1463953acd'])
# Out:
# [Document(id='62c9a0e6-0344-4a47-b30d-cc1463953acd', metadata={}, page_content="navigating a dark part of the internet with no oversight. That's\nwhy we're being so careful. So do everything with extra precautions.\nWhen you download something, maybe disconnect from the internet\nbefore you try to open it. That thing might explode if\nit's connected to the internet. And when I say explode, I mean it might connect with some\nother system or service and hack you or something that can happen. Now, these risks are lower when you're using\nTales Linux on a portable U S B or you're using the network\nChuck Cloud browser. But don't become one of those scary\nstories that people talk about when they mention the dark web. Stay safe.")]

# %% [markdown]
# ## Step 2 - Retrieval

# %%
retriever = vector_store.as_retriever(search_type="similarity", search_kwargs={"k": 4})

# %%
retriever.invoke("What is DarkWeb")
# Out:
# [Document(id='1ff87b25-f2bc-4341-bf92-e2b8b24be939', metadata={}, page_content="Before you try to access the dark web, let me show you how to do it safely\nand securely. I'll show you three ways, starting with the most insecure\nway, the way you're about to try. You're going to get hacked and then\nI'll end with the most secure way, like you're invisible, that can't\ntouch you. You're Edward Snowden, Snowden level security, kind\nof a cool name for a company. Actually dips before we go to\nnumber one, and I'll let you loose. You got to know the\ndark web isn't all bad. It was actually created with good\nintentions to give people anonymity and a platform for free expression, and\nit has a ton of legitimate uses. So think journalists try to communicate\nwith people who want to stay hidden like Edward Snowden or people trying to\nkeep their activities hidden from their government like Edward Snowden. Or if you want to play chess\nwithout anybody watching, yes, you can play chess on the 
# ...

# %%
retriever
# Out:
# VectorStoreRetriever(tags=['FAISS', 'OpenAIEmbeddings'], vectorstore=<langchain_community.vectorstores.faiss.FAISS object at 0x0000018108C32690>, search_kwargs={'k': 4})

# %% [markdown]
# ## Step 3 - Augmentation

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.2)

# %%
prompt = PromptTemplate(
    template="""
      You are a helpful assistant.
      Answer ONLY from the provided transcript context.
      If the context is insufficient, just say you don't know.

      {context}
      Question: {question}
    """,
    input_variables = ['context', 'question']
)

# %%
question          = "is the topic of dark web discussed in this video? if yes then what was discussed"
retrieved_docs    = retriever.invoke(question)

# %%
retrieved_docs
# Out:
# [Document(id='b55cdbd5-d7f9-4420-b83f-aef604a1c7c2', metadata={}, page_content="keep their activities hidden from their government like Edward Snowden. Or if you want to play chess\nwithout anybody watching, yes, you can play chess on the dark web like\nEdward Snowden. I think he plays chess, right? But seriously, the dark web is kind of a good place with\nlegitimate websites like the New York Times, B B C C I A, Facebook, it's all there ready to be\naccessed securely and it's awesome. But what makes it awesome also makes\nit kind of terrifying because it's the perfect breeding ground for all\ntypes of illegal activity. I mean, think about it. If you're a criminal,\nit's perfect anonymity with no oversight. It's like the purge all the time,\nexcept in the internet. And by the way, did you know that your stuff is for\nsale in this place? The dark web, your emails, your passwords,\nyour logins, it's there. Criminals are buying it as we speak. How do I know that you can use what I\nuse 
# ...

# %%
context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
context_text
# Out:
# "keep their activities hidden from their government like Edward Snowden. Or if you want to play chess\nwithout anybody watching, yes, you can play chess on the dark web like\nEdward Snowden. I think he plays chess, right? But seriously, the dark web is kind of a good place with\nlegitimate websites like the New York Times, B B C C I A, Facebook, it's all there ready to be\naccessed securely and it's awesome. But what makes it awesome also makes\nit kind of terrifying because it's the perfect breeding ground for all\ntypes of illegal activity. I mean, think about it. If you're a criminal,\nit's perfect anonymity with no oversight. It's like the purge all the time,\nexcept in the internet. And by the way, did you know that your stuff is for\nsale in this place? The dark web, your emails, your passwords,\nyour logins, it's there. Criminals are buying it as we speak. How do I know that you can use what I\nuse to find out and keep myself safe? Dashlane the sponsor of this video\n\nBefore 
# ...

# %%
final_prompt = prompt.invoke({"context": context_text, "question": question})

# %%
final_prompt
# Out:
# StringPromptValue(text="\n      You are a helpful assistant.\n      Answer ONLY from the provided transcript context.\n      If the context is insufficient, just say you don't know.\n\n      keep their activities hidden from their government like Edward Snowden. Or if you want to play chess\nwithout anybody watching, yes, you can play chess on the dark web like\nEdward Snowden. I think he plays chess, right? But seriously, the dark web is kind of a good place with\nlegitimate websites like the New York Times, B B C C I A, Facebook, it's all there ready to be\naccessed securely and it's awesome. But what makes it awesome also makes\nit kind of terrifying because it's the perfect breeding ground for all\ntypes of illegal activity. I mean, think about it. If you're a criminal,\nit's perfect anonymity with no oversight. It's like the purge all the time,\nexcept in the internet. And by the way, did you know that your stuff is for\nsale in this place? The dark web, your emails, your passwo
# ...

# %% [markdown]
# ## Step 4 - Generation

# %%
answer = llm.invoke(final_prompt)
print(answer)
# Out:
# content='Yes, the topic of the dark web is discussed in this video. It covers the following points:\n\n1. The dark web allows individuals to keep their activities hidden from their government and provides anonymity, similar to what Edward Snowden experienced.\n2. It contains legitimate websites like the New York Times, BBC, and Facebook, but it is also a breeding ground for illegal activities due to the anonymity it offers.\n3. Personal information, such as emails and passwords, can be bought by criminals on the dark web.\n4. The video introduces the Tor browser, which is used to access the dark web, explaining that it routes data through multiple onion routers for security and anonymity.\n5. The dark web was created with good intentions for free expression and anonymity, with legitimate uses like helping journalists communicate securely.\n6. The video promotes Dashlane as a tool to help keep personal information safe from being compromised on the dark web.' additional_kwargs={'refus
# ...

# %% [markdown]
# # Building a Chain

# %%
from langchain_core.runnables import RunnableParallel, RunnablePassthrough, RunnableLambda
from langchain_core.output_parsers import StrOutputParser

# %%
def format_docs(retrieved_docs):
  context_text = "\n\n".join(doc.page_content for doc in retrieved_docs)
  return context_text

# %%
parallel_chain = RunnableParallel({
    'context': retriever | RunnableLambda(format_docs),
    'question': RunnablePassthrough()
})

# %%
parallel_chain.invoke('what is darkweb')
# Out:
# {'context': "Before you try to access the dark web, let me show you how to do it safely\nand securely. I'll show you three ways, starting with the most insecure\nway, the way you're about to try. You're going to get hacked and then\nI'll end with the most secure way, like you're invisible, that can't\ntouch you. You're Edward Snowden, Snowden level security, kind\nof a cool name for a company. Actually dips before we go to\nnumber one, and I'll let you loose. You got to know the\ndark web isn't all bad. It was actually created with good\nintentions to give people anonymity and a platform for free expression, and\nit has a ton of legitimate uses. So think journalists try to communicate\nwith people who want to stay hidden like Edward Snowden or people trying to\nkeep their activities hidden from their government like Edward Snowden. Or if you want to play chess\nwithout anybody watching, yes, you can play chess on the dark web like\n\nlike this. That's the dark web. It's a bunch of we
# ...

# %%
parser = StrOutputParser()

# %%
main_chain = parallel_chain | prompt | llm | parser

# %%
main_chain.invoke('Can you summarize the video')
# Out:
# "The video demonstrates how to use Tails Linux and the Tor network for anonymous browsing. It explains the process of setting up a USB stick with Tails, booting from it, and connecting to the internet securely. The presenter emphasizes the importance of using a VPN before connecting to Tor to hide the user's IP address from their Internet Service Provider (ISP) and the first onion router. The video also shows how to download and install the Tor browser, connect to the dark web, and highlights that users can access both dark web sites and regular websites (clearnet) using the Tor browser. The presenter uses metaphors, like comparing the dark web to interconnected onions, to illustrate the concept of anonymity online."
